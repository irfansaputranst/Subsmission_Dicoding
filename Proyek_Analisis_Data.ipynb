# %% [markdown]
# ## Proyek Analisis Data: **E-Commerce Public Dataset**
#
# *   **Nama:** Irfan Saputra Nasution
# *   **Email:** irfansapurtra969@gmail.com
# *   **ID Dicoding:** irfan101019

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis
#
# *   Berapa banyak uang yang dikeluarkan oleh pelanggan setiap tahun?
# *   Produk apa saja yang paling banyak laku?
# *   Negara mana saja yang memiliki pelanggan terbanyak?
# *   Berapa tingkat kepuasan terhadap customer?

# %% [markdown]
# ### Menyiapkan Library Yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.image as mpimg
# !pip install unidecode
import unidecode
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# ...
# Mounted at /content/gdrive

# %% [markdown]
# ## 1. Data Wrangling

# %% [markdown]
# ### 1.1 Gathering Data

# %% [markdown]
# *Mengambil Keseluruhan Data*

# %%
# Mengambil Data
customer_df = pd.read_csv('/content/gdrive/MyDrive/Colab_Notebooks/E_Commerce_Public_Dataset/customers_dataset.csv')
customer_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
# Mengambil Data Geolocation
geolocation_df = pd.read_csv('/content/gdrive/MyDrive/Colab_Notebooks/E_Commerce_Public_Dataset/geolocation_dataset.csv')
geolocation_df.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
# Mengambil Data Order Items
orderItems_df = pd.read_csv('/content/gdrive/MyDrive/Colab_Notebooks/E_Commerce_Public_Dataset/order_items_dataset.csv')
orderItems_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
# Mengambil Data Order Payment
orderPayments_df = pd.read_csv('/content/gdrive/MyDrive/Colab_Notebooks/E_Commerce_Public_Dataset/order_payments_dataset.csv')
orderPayments_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
# Mengambil Data Order Reviews
orderReviews_df = pd.read_csv('/content/gdrive/MyDrive/Colab_Notebooks/E_Commerce_Public_Dataset/order_reviews_dataset.csv')
orderReviews_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
# Mengambil Data Order
orders_df = pd.read_csv('/content/gdrive/MyDrive/Colab_Notebooks/E_Commerce_Public_Dataset/orders_dataset.csv')
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
# Mengambil Data Product Category
productCategory_df = pd.read_csv('/content/gdrive/MyDrive/Colab_Notebooks/E_Commerce_Public_Dataset/product_category_name_translation.csv')
productCategory_df.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
# Mengambil Data Product
product_df = pd.read_csv('/content/gdrive/MyDrive/Colab_Notebooks/E_Commerce_Public_Dataset/products_dataset.csv')
product_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
# Mengambil Data Sellers
sellers_df = pd.read_csv('/content/gdrive/MyDrive/Colab_Notebooks/E_Commerce_Public_Dataset/sellers_dataset.csv')
sellers_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# ### 1.2 Assessing Data

# %% [markdown]
# *Menilai Kualitas dari Data Tersebut*

# %%
print('\n', customer_df.info())
print('\n', geolocation_df.info())
print('\n', orderPayments_df.info())
print('\n', orderItems_df.info())
print('\n', orderReviews_df.info())
print('\n', orders_df.info())
print('\n', product_df.info())
print('\n', productCategory_df.info())
print('\n', sellers_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB
#
#  None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
# ...

# %%
print("Jumlah duplikasi pada data Customer:  \n", customer_df.duplicated().sum())
print("Jumlah duplikasi pada data Geolocation:  \n", geolocation_df.duplicated().sum())
print("Jumlah duplikasi pada data Order Items:  \n", orderItems_df.duplicated().sum())
print("Jumlah duplikasi pada data Order Payments:  \n", orderPayments_df.duplicated().sum())
print("Jumlah duplikasi pada data Order Reviews:  \n", orderReviews_df.duplicated().sum())
print("Jumlah duplikasi pada data Order:  \n", orders_df.duplicated().sum())
print("Jumlah duplikasi pada data Product Category Name:  \n", productCategory_df.duplicated().sum())
print("Jumlah duplikasi pada data Product:  \n", product_df.duplicated().sum())
print("Jumlah duplikasi pada data Sellers:  \n", sellers_df.duplicated().sum())
# Out:
# Jumlah duplikasi pada data Customer:
#  0
# Jumlah duplikasi pada data Geolocation:
#  261831
# Jumlah duplikasi pada data Order Items:
#  0
# Jumlah duplikasi pada data Order Payments:
#  0
# Jumlah duplikasi pada data Order Reviews:
#  0
# Jumlah duplikasi pada data Order:
#  0
# Jumlah duplikasi pada data Product Category Name:
#  0
# Jumlah duplikasi pada data Product:
#  0
# Jumlah duplikasi pada data Sellers:
#  0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# *Melihat Berapa Data NULL*

# %%
print("Jumlah NULL pada data Customer:  \n", customer_df.isnull().sum())
print("Jumlah NULL pada data Geolocation:  \n", geolocation_df.isnull().sum())
print("Jumlah NULL pada data Order Items:  \n", orderItems_df.isnull().sum())
print("Jumlah NULL pada data Order Payments:  \n", orderPayments_df.isnull().sum())
print("Jumlah NULL pada data Order Reviews:  \n", orderReviews_df.isnull().sum())
print("Jumlah NULL pada data Order:  \n", orders_df.isnull().sum())
print("Jumlah NULL pada data Product Category Name:  \n", productCategory_df.isnull().sum())
print("Jumlah NULL pada data Product:  \n", product_df.isnull().sum())
print("Jumlah NULL pada data Sellers:  \n", sellers_df.isnull().sum())
# Out:
# Jumlah NULL pada data Customer:
#  customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64
# Jumlah NULL pada data Geolocation:
#  geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64
# Jumlah NULL pada data Order Items:
#  order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64
# Jumlah NULL pada data Order Payments:
#  order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64
# Jumlah NULL pada data Order Reviews:
#  review_id                      0
# order_id                       0
# ...

# %% [markdown]
# *Melihat Keseluruhan Data*

# %%
print("\n Data Describe pada data Customer:  \n", customer_df.describe(include='all'))
print("\n Data Describe pada data Geolocation:  \n", geolocation_df.describe(include='all'))
print("\n Data Describe pada data Order Items:  \n", orderItems_df.describe(include='all'))
print("\n Data Describe pada data Order Payments:  \n", orderPayments_df.describe(include='all'))
print("\n Data Describe pada data Order Reviews:  \n", orderReviews_df.describe(include='all'))
print("\n Data Describe pada data Order:  \n", orders_df.describe(include='all'))
print("\n Data Describe pada data Product Category Name:  \n", productCategory_df.describe(include='all'))
print("\n Data Describe pada data Product:  \n", product_df.describe(include='all'))
print("\n Data Describe pada data Sellers:  \n", sellers_df.describe(include='all'))
# Out:
#  Data Describe pada data Customer:
#                               customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
# ...

# %% [markdown]
# ### 1.3 Cleaning Data

# %% [markdown]
# Data pada Geolocation banyak sekitar 261831 yang kemungkinannya terjadi di kolom *'geolocation_state' & 'geolocation_city'*. Maka tidak dilakukannya drop duplikat secara langsung

# %%
orderReviews_df[orderReviews_df.review_comment_title.isna()]
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %%
orderReviews_df.review_comment_title.value_counts()
# Out:
# Recomendo                    423
# recomendo                    345
# Bom                          293
# super recomendo              270
# Excelente                    248
#                             ...
# Luminaria sobrepor led 18      1
# Não recebi.                    1
# produto com lacre violado      1
# Atraso Entrega                 1
# Foto enganosa                  1
# Name: review_comment_title, Length: 4527, dtype: int64

# %%
orderReviews_df[orderReviews_df.review_comment_message.isna()]
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 5      15197aa66ff4d0650b5434f1b46cda19  b18dcdf73be66366873cd26c5724d1dc
# 6      07f9bee5d1b850860defd761afa7ff16  e48aa0d2dcec3a2e87348811bcfdf22b
# ...                                 ...                               ...
# 99217  c6b270c61f67c9f7cb07d84ea8aeaf8b  48f7ee67313eda32bfcf5b9c1dd9522d
# 99218  af2dc0519de6e0720ef0c74292fb4114  d699c734a0b1c8111f2272a3f36d398c
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
#
#        review_score review_comment_title review_comment_message  \
# ...

# %%
orderReviews_df.review_comment_message.value_counts()
# Out:
# Muito bom                                                                                                                                                                                              230
# Bom                                                                                                                                                                                                    189
# muito bom                                                                                                                                                                                              122
# bom                                                                                                                                                                                                    107
# ...

# %%
orderReviews_df.fillna(value="No Comment", inplace=True)

# %%
orderReviews_df.review_comment_message.value_counts()
# Out:
# No Comment                                                                                                                                                                                             58247
# Muito bom                                                                                                                                                                                                230
# Bom                                                                                                                                                                                                      189
# muito bom                                                                                                                                                                                                122
# ...

# %%
orders_df[orders_df.order_approved_at.isna()]
# Out:
#                                order_id                       customer_id  \
# 1130   00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 1801   ed3efbd3a87bea76c2812c66a0b32219  191984a8ba4cbb2145acb4fe35b69664
# 1868   df8282afe61008dc26c6c31011474d02  aa797b187b5466bc6925aaaa4bb3bed1
# 2029   8d4c637f1accf7a88a4555f02741e606  b1dd715db389a2077f43174e7a675d07
# 2161   7a9d4c7f9b068337875b95465330f2fc  7f71ae48074c0cfec9195f88fcbfac55
# ...                                 ...                               ...
# 97696  5a00b4d35edffc56b825c3646a99ba9d  6a3bdf004ca96338fb5fad1b8d93c2e6
# 98415  227c804e2a44760671a6a5697ea549e4  62e7477e75e542243ee62a0ba73f410f
# 98909  e49e7ce1471b4693482d40c2bd3ad196  e4e7ab3f449aeb401f0216f86c2104db
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
#
#       order_status order_purchase_timestamp order_approved_at  \
# ...

# %%
# Mengganti tipe data "Shipping Limit Date"
datetime_columns = ["shipping_limit_date"]

for column in datetime_columns:
  orderItems_df[column] = pd.to_datetime(orderItems_df[column])

# %%
orderItems_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %%
# Mengganti tipe data "Review Creation Date dan Review Answer Timestamp"
datetime_columns = ["review_creation_date", "review_answer_timestamp"]

for column in datetime_columns:
  orderReviews_df[column] = pd.to_datetime(orderReviews_df[column])

# %%
orderReviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     99224 non-null  object
#  4   review_comment_message   99224 non-null  object
#  5   review_creation_date     99224 non-null  datetime64[ns]
#  6   review_answer_timestamp  99224 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 5.3+ MB

# %%
# Mengganti tipe data "Order Delivered Carrier Date, Order Delivered Customer Date, Order Estimated Delivery Date"
datetime_orders = ["order_delivered_carrier_date", "order_delivered_customer_date", "order_estimated_delivery_date"]

for column in datetime_orders:
  orders_df[column] = pd.to_datetime(orders_df[column])

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), object(5)
# memory usage: 6.1+ MB

# %% [markdown]
# ## Exploratory Data Analysisis (EDA)

# %% [markdown]
# ### Explore Data customer_df

# %%
customer_df.sample(5)
# Out:
#                             customer_id                customer_unique_id  \
# 48041  ea229107a6c42936eb9b5381d4ded0d4  3f17d7bca51f27e962ce6071a08434ed
# 30732  f1a239b72ea3fade1066471be5a5eb27  163fb9fbf2ad50509f49ff664893b6b8
# 83553  b8573f83c3ba6abfabadfe32bf332f99  6303615cbe542bafde4c65ccca85c01b
# 62067  9955ed1a34b90186a17b885d97f9aef9  6b1accda38fc6c15f411ddcdd8a109ac
# 93625  c066d28a9507feed4ba59f8b63e44c2b  2a09d2659a237c88102c3ccfe70a1e91
#
#        customer_zip_code_prefix      customer_city customer_state
# 48041                     12919  braganca paulista             SP
# 30732                      8032          sao paulo             SP
# 83553                     18120          mairinque             SP
# 62067                      2969          sao paulo             SP
# 93625                     11025             santos             SP

# %%
customer_df.describe(include="all")
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %%
customer_df.customer_id.is_unique
# Out:
# True

# %%
# Melihat persebaran pelanggan di berbagai kota
customer_df.groupby(by="customer_city").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# ibiara                1
# rio espera            1
# rio dos indios        1
# rio dos cedros        1
# lagoao                1
# Name: customer_id, Length: 4119, dtype: int64

# %%
# Melihat persebaran pelanggan di berbagai negara
customer_df.groupby(by="customer_state").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: customer_id, dtype: int64

# %% [markdown]
# ### Explore Data orderPayments_df

# %%
orderPayments_df.sample(5)
# Out:
#                                order_id  payment_sequential payment_type  \
# 25799  8daeaeb312867695e95090559c5aaaef                   1  credit_card
# 53930  48d5b6816e1f11f1272000b4af1fd7ed                   1  credit_card
# 44214  d02a0111cedc20a548cb065955e04968                   1  credit_card
# 22931  773f350ab7f485f0d4aa1a095820fedd                   1       boleto
# 94482  38f4de107b2ebaed574ce9233ad3f261                   1  credit_card
#
#        payment_installments  payment_value
# 25799                     1          45.65
# 53930                     8         162.93
# 44214                     4         198.90
# 22931                     1          43.09
# 94482                     2         163.78

# %%
orderPayments_df.describe(include="all")
# Out:
#                                 order_id  payment_sequential payment_type  \
# count                             103886       103886.000000       103886
# unique                             99440                 NaN            5
# top     fa65dad1b0e818e3ccc5cb0e39231352                 NaN  credit_card
# freq                                  29                 NaN        76795
# mean                                 NaN            1.092679          NaN
# std                                  NaN            0.706584          NaN
# min                                  NaN            1.000000          NaN
# 25%                                  NaN            1.000000          NaN
# 50%                                  NaN            1.000000          NaN
# 75%                                  NaN            1.000000          NaN
# max                                  NaN           29.000000          NaN
#
#         payment_installments  payment_value
# ...

# %%
orderPayments_df.groupby(by="payment_type").order_id.nunique().sort_values(ascending=False)
# Out:
# payment_type
# credit_card    76505
# boleto         19784
# voucher         3866
# debit_card      1528
# not_defined        3
# Name: order_id, dtype: int64

# %% [markdown]
# ### Explore Data order_df

# %%
orders_df.sample(5)
# Out:
#                                order_id                       customer_id  \
# 74701  964267c31e3140c22ce0eb459a4cfb72  3f935515a6dcad83cb626a199b5f7981
# 97351  d413cfcd1406d2d501179c9671b727fd  7dc2f6bec48604fdb13d3a250a92ce89
# 56107  03681e41ebddb2ca0241b148a40773d0  6112ec2abfe626685bd8c15e3e188304
# 91153  0b93ee12012954d6b2a2c9a69ce4fd24  229765fae12044b31cc0dd891f42d19d
# 36124  b662aa8d6c39f00e854cd5142e2b1174  b558dbb371f5e955bc68b7500fa46fe7
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 74701    delivered      2018-08-23 19:57:18  2018-08-23 20:10:16
# 97351    delivered      2018-06-28 23:44:21  2018-06-28 23:55:10
# 56107    delivered      2017-10-23 10:48:50  2017-10-23 11:10:18
# 91153    delivered      2018-01-15 10:45:12  2018-01-15 10:57:22
# 36124    delivered      2017-03-27 13:31:57  2017-03-28 03:56:18
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# ...

# %%
delivery_time = orders_df["order_delivered_customer_date"] - orders_df["order_delivered_carrier_date"]
delivery_time = delivery_time.apply(lambda x: x.total_seconds())
orders_df["delivery_time"] = round(delivery_time/86400)

# %%
orders_df.describe(include="all", datetime_is_numeric=True)
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
# mean                                 NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
# std                                  NaN                               NaN
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
orders_df.sample(5)
# Out:
#                                order_id                       customer_id  \
# 77704  4caa878dd26539c88f5243c6bd277ad5  1bfb8cb079b0c028107b3fe473234ca6
# 86133  0cf8368e4bd533308d1d3b77bd9f2844  300b0dd79dc0dd388ee25b66631ea2ef
# 82791  a43959b4fa84405a58554cfe776350fd  afef0262c47697a580a62eb254dd23a0
# 97894  798c01f3a7c277a170c5a669935fb85b  378bdab88fcf7182b0d5c82dd755c3d4
# 5603   b49fb5d1cf86975cf5a295431c278a33  919898139ad85605b36f05302f908a95
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 77704    delivered      2017-09-26 11:35:30  2017-09-26 11:49:22
# 86133    delivered      2017-07-12 21:25:11  2017-07-13 17:30:11
# 82791    delivered      2017-06-30 14:17:12  2017-06-30 14:25:13
# 97894    delivered      2017-04-11 20:22:44  2017-04-12 02:45:51
# 5603     delivered      2018-06-11 18:18:36  2018-06-12 18:46:06
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# ...

# %%
customer_id_in_orders_df = orders_df.customer_id.values
customer_df["status"] = customer_df["customer_id"].apply(lambda x: "Active" if x in customer_id_in_orders_df else "Non Active")
customer_df.sample(5)
# Out:
#                             customer_id                customer_unique_id  \
# 2586   00bae1a0d3566c3af0c3c67fd2204935  66d201c13937598dd4e036788a10a203
# 12465  1f45dccd4cee402a119e6fe3edde26c5  31d671b9dc337c7844e0ad268bd27685
# 81190  8f8b86d98300c3e0c6e84c4fcc8a4581  6b0549ae5aa9d8289356b678ccad1409
# 12967  b6f67adc8721fca02d68c6882cb29cc9  4cc11072c33f1b37d77d79379a70eb23
# 31338  ba0bfb46dd7216784ecd3695c4ee60d0  90268bc0fa504821ccaba5d9e8d0c07d
#
#        customer_zip_code_prefix    customer_city customer_state  status
# 2586                      38465          arapora             MG  Active
# 12465                     18076         sorocaba             SP  Active
# 81190                     24452      sao goncalo             RJ  Active
# 12967                     13053         campinas             SP  Active
# 31338                     13510  santa gertrudes             SP  Active

# %%
customer_df.groupby(by="status").customer_id.count()
# Out:
# status
# Active    99441
# Name: customer_id, dtype: int64

# %% [markdown]
# ### Explore Data customer_df dan orders_df

# %%
customerOrder_df = pd.merge(
    left=customer_df,
    right=orders_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)

customerOrder_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  status  \
# 0                     14409                 franca             SP  Active
# 1                      9790  sao bernardo do campo             SP  Active
# 2                      1151              sao paulo             SP  Active
# 3                      8775        mogi das cruzes             SP  Active
# 4                     13056               campinas             SP  Active
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
# Menghitung Pelanggan di Berbagai Kota
customerOrder_df.groupby(by="customer_city").order_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# ibiara                1
# rio espera            1
# rio dos indios        1
# rio dos cedros        1
# lagoao                1
# Name: order_id, Length: 4119, dtype: int64

# %%
# Menghitung Pelanggan di Berbagai Negara
customerOrder_df.groupby(by="customer_state").order_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: order_id, dtype: int64

# %% [markdown]
# ### Explore Data orderPayments_df & orderReviews_df

# %%
orderPaymentsReviews_df = pd.merge(
    left=orderPayments_df,
    right=orderReviews_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)

orderPaymentsReviews_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
#
#    payment_installments  payment_value                         review_id  \
# 0                     8          99.33  4ce650e117a5b292bf5ea980a61eb61e
# 1                     1          24.39  ad2036caca61484fc435d7e673c020f2
# 2                     1          65.71  bcddfa0f7d2e54cfc74bae4f01b84d92
# 3                     8         107.78  c37a0e51e5df82bdb55d38ff0ffb6af3
# 4                     8         107.78  5bc7680443b4ef765fec11a8201eeb0c
#
#    review_score review_comment_title  \
# 0           1.0        Não recomendo
# ...

# %%
# Menghitung Tipe Pembayaran
orderPaymentsReviews_df.groupby(by="payment_type").order_id.nunique().sort_values(ascending=False)
# Out:
# payment_type
# credit_card    76505
# boleto         19784
# voucher         3866
# debit_card      1528
# not_defined        3
# Name: order_id, dtype: int64

# %%
# Menghitung Values dari Pembayaran
orderPaymentsReviews_df.sort_values(by="payment_value", ascending=False)
# Out:
#                                order_id  payment_sequential payment_type  \
# 52415  03caa2c082116e1d31e67e9ae3700499                   1  credit_card
# 34565  736e1922ae60d0d6a89247b851902527                   1       boleto
# 41660  0812eb902a67711a1cb742b3cdaa65ae                   1  credit_card
# 49871  fefacc66af859508bf1a7934eab1e97f                   1       boleto
# 86018  f5136e38d1a14a4dbd87dff67da82701                   1       boleto
# ...                                 ...                 ...          ...
# 78326  fa65dad1b0e818e3ccc5cb0e39231352                  13      voucher
# 51581  4637ca194b6387e2d538dc89b124b0ee                   1  not_defined
# 37030  fa65dad1b0e818e3ccc5cb0e39231352                  14      voucher
# 94953  c8c528189310eaa44a745b8d9d26908b                   1  not_defined
# 20031  8bcbe01d44d147f901cd3192671144db                   4      voucher
#
#        payment_installments  payment_value                         review_id  \
# ...

# %%
# Menghitung Values Tipe Pembayaran (Min dan Max)
orderPaymentsReviews_df.groupby(by="payment_type").agg({
    "order_id": "nunique",
    "payment_value": ["min", "max"]
})
# Out:
#              order_id payment_value
#               nunique           min       max
# payment_type
# boleto          19784         11.62   7274.88
# credit_card     76505          0.01  13664.08
# debit_card       1528         13.38   4445.50
# not_defined         3          0.00      0.00
# voucher          3866          0.00   3184.34

# %% [markdown]
# ### Explore Data customerOrder_df & orderPaymentReviews_df

# %%
custOrdPayRev_df = pd.merge(
    left=customerOrder_df,
    right=orderPaymentsReviews_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)

custOrdPayRev_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  status  \
# 0                     14409                 franca             SP  Active
# 1                      9790  sao bernardo do campo             SP  Active
# 2                      1151              sao paulo             SP  Active
# 3                      8775        mogi das cruzes             SP  Active
# 4                     13056               campinas             SP  Active
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %% [markdown]
# ### Explore Data orderItems_df & sellers_df

# %%
orderItemSel_df = pd.merge(
    left=orderItems_df,
    right=sellers_df,
    how="left",
    left_on="seller_id",
    right_on="seller_id"
)

orderItemSel_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  seller_zip_code_prefix  \
# 0 2017-09-19 09:45:35   58.90          13.29                   27277
# 1 2017-05-03 11:05:13  239.90          19.93                    3471
# ...

# %%
# Menghitung Penjual dari berbagai kota
orderItemSel_df.groupby(by="seller_city").seller_id.nunique().sort_values(ascending=False)
# Out:
# seller_city
# sao paulo         694
# curitiba          127
# rio de janeiro     96
# belo horizonte     68
# ribeirao preto     52
#                  ...
# ivoti               1
# itirapina           1
# itau de minas       1
# itapui              1
# xaxim               1
# Name: seller_id, Length: 611, dtype: int64

# %% [markdown]
# ### Explore Data product_df & productCategory_df

# %%
products_df = pd.merge(
    left=product_df,
    right=productCategory_df,
    how="left",
    left_on="product_category_name",
    right_on="product_category_name"
)

products_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# ...

# %%
# Menghitung Kategori Produk
products_df.groupby(by="product_category_name").product_id.nunique().sort_values(ascending=False)
# Out:
# product_category_name
# cama_mesa_banho                  3029
# esporte_lazer                    2867
# moveis_decoracao                 2657
# beleza_saude                     2444
# utilidades_domesticas            2335
#                                  ...
# casa_conforto_2                     5
# fashion_roupa_infanto_juvenil       5
# pc_gamer                            3
# seguros_e_servicos                  2
# cds_dvds_musicais                   1
# Name: product_id, Length: 73, dtype: int64

# %% [markdown]
# ### Explore Data orderItemSel_df & products_df

# %%
productSeller_df = pd.merge(
    left=products_df,
    right=orderItemSel_df,
    how="left",
    left_on="product_id",
    right_on="product_id"
)

productSeller_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# ...

# %%
# Menghitung Values Product dari Seller
productSeller_df.sort_values(by="price", ascending=False)
# Out:
#                              product_id              product_category_name  \
# 20528  489ae2aa008f021502940f251d4cce7f              utilidades_domesticas
# 73922  69c590f7ffc7bf8db97190b6cb6ed62e                                pcs
# 49503  1bdf5e6731585cf01aa8169c7028d6ad                              artes
# 71835  a6492cc69376c469ab6f61d8f44de961                    eletroportateis
# 32232  c3ed642d592594bb648ff4a04cee2747                    eletroportateis
# ...                                 ...                                ...
# 55911  05b515fdc76e888aada3c6d66c201dff                       beleza_saude
# 55903  05b515fdc76e888aada3c6d66c201dff                       beleza_saude
# 29610  8a3254bee785a526d548a81a9bc3c9be  construcao_ferramentas_construcao
# 29608  8a3254bee785a526d548a81a9bc3c9be  construcao_ferramentas_construcao
# 29609  8a3254bee785a526d548a81a9bc3c9be  construcao_ferramentas_construcao
#
# ...

# %%
productSeller_df.groupby(by="product_category_name_english").agg({
    "order_id": "nunique",
    "price": ["min", "max"]
})
# Out:
#                               order_id  price
#                                nunique    min      max
# product_category_name_english
# agro_industry_and_commerce         182  12.99  2990.00
# air_conditioning                   253  10.90  1599.00
# art                                202   3.50  6499.00
# arts_and_craftmanship               23   9.80   289.49
# audio                              350  14.90   598.99
# ...                                ...    ...      ...
# stationery                        2311   2.29  1693.00
# tablets_printing_image              79  14.90   889.99
# telephony                         4199   5.00  2428.00
# toys                              3886   4.90  1699.99
# watches_gifts                     5624   8.99  3999.90
#
# [71 rows x 3 columns]

# %% [markdown]
# ### Explore Data geolocation_df

# %%
geolocation_df.sample(5)
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 892083                        86960       -24.023051       -52.000698
# 106323                         4714       -23.634451       -46.695108
# 827251                        78525       -10.167366       -54.934979
# 219553                         9040       -23.661812       -46.532109
# 113791                         5017       -23.538688       -46.681094
#
#        geolocation_city geolocation_state
# 892083   barbosa ferraz                PR
# 106323        sao paulo                SP
# 827251           matupa                MT
# 219553      santo andré                SP
# 113791        sao paulo                SP

# %%
def string_pre(column):
  column_space = ' '.join(column.split())
  return unidecode.unidecode(column_space.lower())

# %%
geolocation_df['geolocation_city'] = geolocation_df['geolocation_city'].apply(string_pre)

# %%
geolocation_df.groupby('geolocation_zip_code_prefix').size().sort_values(ascending=False)
# Out:
# geolocation_zip_code_prefix
# 24220    1146
# 24230    1102
# 38400     965
# 35500     907
# 11680     879
#          ...
# 20056       1
# 76370       1
# 63012       1
# 76372       1
# 32635       1
# Length: 19015, dtype: int64

# %%
geolocation_df[geolocation_df['geolocation_zip_code_prefix'] == 24220].head()
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 470805                        24220       -22.905817       -43.106989
# 470811                        24220       -22.902306       -43.112545
# 470812                        24220       -22.904567       -43.110491
# 470820                        24220       -22.902575       -43.109192
# 470821                        24220       -22.907500       -43.106170
#
#        geolocation_city geolocation_state
# 470805          niteroi                RJ
# 470811          niteroi                RJ
# 470812          niteroi                RJ
# 470820          niteroi                RJ
# 470821          niteroi                RJ

# %% [markdown]
# ## Explore ALL Data

# %% [markdown]
# Pada kasus saya ini tidak menggabungkan data pada geolocation_df, karena dataset tersebut tidak diperlukan

# %%
all_data = pd.merge(
    left=custOrdPayRev_df,
    right=productSeller_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
all_data.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  status  \
# 0                     14409                 franca             SP  Active
# 1                      9790  sao bernardo do campo             SP  Active
# 2                      1151              sao paulo             SP  Active
# 3                      8775        mogi das cruzes             SP  Active
# 4                     13056               campinas             SP  Active
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119143 entries, 0 to 119142
# Data columns (total 42 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   customer_id                    119143 non-null  object
#  1   customer_unique_id             119143 non-null  object
#  2   customer_zip_code_prefix       119143 non-null  int64
#  3   customer_city                  119143 non-null  object
#  4   customer_state                 119143 non-null  object
#  5   status                         119143 non-null  object
#  6   order_id                       119143 non-null  object
#  7   order_status                   119143 non-null  object
#  8   order_purchase_timestamp       119143 non-null  object
#  9   order_approved_at              118966 non-null  object
#  10  order_delivered_carrier_date   117057 non-null  datetime64[ns]
#  11  order_delivered_customer_date  115722 non-null  datetime64[ns]
# ...

# %%
all_data.groupby(by=["customer_city", "product_category_name_english"]).agg({
    "price": "sum",
    "freight_value": "sum"
})
# Out:
#                                                     price  freight_value
# customer_city       product_category_name_english
# abadia dos dourados books_general_interest          39.90          18.38
#                     cool_stuff                     199.00          20.63
#                     sports_leisure                 120.00          15.59
# abadiania           small_appliances               949.99          75.53
# abaete              baby                            65.00          17.70
# ...                                                   ...            ...
# ze doca             food_drink                      65.00          38.00
#                     garden_tools                    39.90          26.61
#                     musical_instruments            359.00          49.04
#                     sports_leisure                 149.90          38.60
# zortea              computers_accessories           69.90          20.98
#
# [25199 rows x 2 columns]

# %%
all_data.groupby(by=["customer_state", "product_category_name_english"]).agg({
    "price": "sum",
    "freight_value": "sum"
})
# Out:
#                                                 price  freight_value
# customer_state product_category_name_english
# AC             auto                            606.97         146.42
#                baby                            697.84         174.13
#                bed_bath_table                  567.70         157.51
#                books_general_interest          633.80         123.71
#                christmas_supplies               69.90          60.95
# ...                                               ...            ...
# TO             sports_leisure                 5533.32        1393.53
#                stationery                      276.80          73.80
#                telephony                      1268.12         627.34
#                toys                           1864.15         423.96
#                watches_gifts                  5446.89         950.02
#
# [1356 rows x 2 columns]

# %%
all_data.groupby(by="customer_state").agg({
    "order_id": "nunique",
    "payment_value": "sum"
}).sort_values(by="payment_value", ascending=False)
# Out:
#                 order_id  payment_value
# customer_state
# SP                 41746     7726078.35
# RJ                 12852     2795615.67
# MG                 11635     2351221.09
# RS                  5466     1160175.66
# PR                  5045     1079795.49
# BA                  3380      805070.98
# SC                  3637      801276.45
# GO                  2020      520481.65
# DF                  2140      438095.32
# ES                  2033      408611.64
# PE                  1652      380294.18
# CE                  1336      349290.36
# PA                   975      263217.70
# MT                   907      257802.26
# MA                   747      200363.24
# PB                   536      181660.73
# MS                   715      167670.27
# PI                   495      137158.89
# RN                   485      117192.91
# AL                   413      112296.47
# SE                   350       90651.44
# TO                   280       72412.08
# ...

# %%
all_data.groupby(by="product_category_name_english").agg({
    "order_id": "nunique",
    "review_score":  ["min", "max"]
})
# Out:
#                               order_id review_score
#                                nunique          min  max
# product_category_name_english
# agro_industry_and_commerce         182          1.0  5.0
# air_conditioning                   253          1.0  5.0
# art                                202          1.0  5.0
# arts_and_craftmanship               23          1.0  5.0
# audio                              350          1.0  5.0
# ...                                ...          ...  ...
# stationery                        2311          1.0  5.0
# tablets_printing_image              79          1.0  5.0
# telephony                         4199          1.0  5.0
# toys                              3886          1.0  5.0
# watches_gifts                     5624          1.0  5.0
#
# [71 rows x 3 columns]

# %% [markdown]
# ## Convert all_data to .csv

# %%
all_data.to_csv('all_data.csv', index=False)

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:
# Berapa banyak uang yang dikeluarkan oleh pelanggan setiap tahun?

# %%
all_data['order_approved_at'] = pd.to_datetime(all_data['order_approved_at'])
years_spend_df = all_data.resample(rule='Y', on='order_approved_at').agg({
    "payment_value": "sum"
})
years_spend_df.index = years_spend_df.index.strftime('%Y')
years_spend_df = years_spend_df.reset_index()
years_spend_df.rename(columns={
    "payment_value": "total_spend"
}, inplace=True)
years_spend_df.head()
# Out:
#   order_approved_at  total_spend
# 0              2016     76005.16
# 1              2017   9311930.14
# 2              2018  11154354.05

# %%
years_spend_df = all_data.resample(rule='Y').agg({
    "payment_value": "sum"
})


plt.figure(figsize=(10, 5))
colors = ["#72BCD4", "#D3D3D3", "#068DA9"]

plt.bar(years_spend_df.index.year, years_spend_df['payment_value'], color=colors)
plt.title('Total Pengeluaran Pelanggan per tahun', fontsize=15)
plt.xlabel('Tahun', fontsize=12)
plt.ylabel('Total Pengeluaran', fontsize=12)
plt.xticks(years_spend_df.index.year)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ### Pertanyaan 2:
# Produk apa saja yang paling banyak laku?

# %%
jum_order_items_df = all_data.groupby("product_category_name_english")["product_id"].count().reset_index()
jum_order_items_df = jum_order_items_df.rename(columns={"product_id": "products"})
jum_order_items_df = jum_order_items_df.sort_values(by="products", ascending=False)
jum_order_items_df = jum_order_items_df.head(5)

jum_order_items_df.head()
# Out:
#    product_category_name_english  products
# 7                 bed_bath_table     11988
# 43                 health_beauty     10032
# 65                sports_leisure      9004
# 39               furniture_decor      8832
# 15         computers_accessories      8150

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(24, 6))

jum_order_items_df_sorted = jum_order_items_df.head(5).sort_values(by="products", ascending=False)

colors = ["#068DA9" if category == jum_order_items_df_sorted.iloc[0]["product_category_name_english"] else "#D3D3D3" for category in jum_order_items_df_sorted["product_category_name_english"]]

sns.barplot(x="products",
            y="product_category_name_english",
            data=jum_order_items_df_sorted,
            hue="product_category_name_english",
            palette=colors)

plt.xlabel("Jumlah Order")
plt.ylabel("Nama Product")
plt.title("Produk paling banyak terjual", loc="center", fontsize=18)
plt.show()

# %% [markdown]
# ## Pertanyaan 3:

# %% [markdown]
# Negara mana saja yang memiliki pelanggan terbanyak?

# %%
bystate_df = all_data.groupby(by="customer_state").customer_id.nunique().reset_index().head(5)
bystate_df.rename(columns={
    "customer_id": "customer_count"
}, inplace=True)
bystate_df
plt.figure(figsize=(10, 5))
palettes = ["#068DA9" if score == bystate_df.index[0] else "#D3D3D3" for score in bystate_df.index]

sns.barplot(
    x="customer_count",
    y="customer_state",
    data=bystate_df.sort_values(by="customer_count", ascending=False),
    hue="customer_state",
    palette = palettes
)
plt.title("Pelanggan Terbanyak berdasarkan Negara", loc="center", fontsize=15)
plt.ylabel("Asal Pelanggan")
plt.xlabel("Jumlah Pelanggan")
plt.tick_params(axis='y', labelsize=12)
plt.show()

# %% [markdown]
# ## Pertanyaan 4:

# %% [markdown]
# Berapa tingkat kepuasan terhadap customer?

# %%
review_scores = all_data['review_score'].value_counts().sort_values(ascending=False)

most_common_score = review_scores.idxmax()

sns.set(style="darkgrid")

plt.figure(figsize=(10, 5))

palette = ["#068DA9" if i == review_scores.index[4] else "#D3D3D3" for i in review_scores.index]

sns.barplot(x=review_scores.index,
            y=review_scores.values,
            order=review_scores.index,
            hue=review_scores.values,
            palette=palette
            )

plt.title("Tingkat Kepuasan Pelanggan", fontsize=15)
plt.legend(title='Jumlah Pelanggan Yang Sudah Review', fontsize=10)
plt.xlabel("Rating")
plt.ylabel("Jumlah Pelanggan")
plt.xticks(fontsize=12)
plt.show()

# %% [markdown]
# ## Conclusion
#
# - Berapa banyak uang yang dikeluarkan oleh pelanggan setiap tahun? ***Pelanggan tiap tahun selalu meningkat dari segi pengeluaran untuk membeli sebuah barang***
#
# - Produk apa saja yang paling banyak laku? ***Produk yang paling banyak laku yang dibeli pelanggan ialah bed_bath_table***
#
# - Negara mana saja yang memiliki pelanggan terbanyak? ***Negara bagian yang memiliki pelanggan terbanyak adalah BA disusul dengan AL dan AM yang berada di urutan 2 dan 3***
#
# - Berapa tingkat kepuasan terhadap customer?***Tingkat kepuasan customer terhadap layanan yang diberikan sangatlah memuaskan dikarenakan pada visualisasi yang sudah ditampilkan memperlihatkan bahwa customer yang memberikan rating 5 sangat banyak, dan rating 4 pada urutan ke-2 terbanyak.***
